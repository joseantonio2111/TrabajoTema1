# %% [markdown]
# <h1><center>Trabajo Tema 1</center></h1>

# %% [markdown]
# ## 1. Un juego de lanzamiento de una moneda

# %% [markdown]
# > **1.** Cada jugada del juego consiste en lanzar repetidamente una moneda imparcial hasta que la diferencia entre el número de caras lanzadas y el número de sellos es 3.
#
# > **2.** Si decides jugar el juego, debes pagar 1 por cada lanzamiento de la moneda. No puedes salir durante una jugada del juego.
#
# > **3.** Usted recibe 8 al final de cada juego del juego. Por lo tanto, ganas dinero si el número de lanzamientos requeridos es menor a 8, pero pierdes dinero si se requieren más de 8 lanzamientos.

# %% [markdown]
# #### Código

# %%
import numpy as np
# Sea 0 cara y 1 sello
tg = []
for j in range(1000):
    c,s,t = 0,0,0
    while abs(s-c) != 3:
        x = np.random.randint(0,2)
        if x == 0:
            c += 1
        else:
            s += 1
        t += 1
    tg.append(t)
    j+=1

# %%
# Pregunta a
print('La media de los tiros necesarios para ganar es:',np.mean(tg))
print('La desv std de los tiros ganadores es:',np.std(tg))
import matplotlib.pyplot as plt
# %matplotlib inline
plt.hist(tg,25,alpha=0.7,normed = True)
plt.grid()
plt.xlabel('Tiros ganadores')
plt.show()
# Out:
# La media de los tiros necesarios para ganar es: 8.968
# La desv std de los tiros ganadores es: 7.30691289123

# %%
# Graficando Normal
from scipy import stats as st
mu, sigma = np.mean(tg), np.std(tg)
normal = st.norm(mu, sigma)
x = np.linspace(normal.ppf(0.01),normal.ppf(0.99), 1000)
fp = normal.pdf(x) # Función de Probabilidad
plt.plot(x, fp)
datos = np.random.normal(mu, sigma, 1000) #creando muestra de datos
plt.hist(datos, 20,normed=True)
plt.title('Distribución Normal')
plt.ylabel('probabilidad')
plt.xlabel('valores')
plt.grid()
plt.show()

# %%
#def frange(start, stop, step):
#    i = start
#    while i < stop:
#        yield i
#        i += step
#        
#for n in frange(0.01, 0.99, 0.01):
#    tiros=normal.ppf(n)
#    print(n,tiros)

#Pregunta b
#Probabilidad de tirar +10 veces
print('La probabilidad de tirar más de 10 veces es',1- normal.cdf(10))
#Probabilidad de tirar -5 veces
print('La probabilidad de tirar menos de 5 veces es',normal.cdf(5))
# Out:
# La probabilidad de tirar más de 10 veces es 0.462784632514
# La probabilidad de tirar menos de 5 veces es 0.291168894117

# %%
#Pregunta c
dt = []
for i in range(1000):
    c,s,t,d = 0,0,0,0
    while t<100:
        x = np.random.randint(0,2)
        if x == 0:
            c += 1
        else:
            s += 1
        t += 1
        d -= 1
        if abs(s-c) == 3:
            d += 8
            c,s = 0,0
        else:
            continue
    dt.append(d)
    i += 1
plt.hist(dt,20,alpha=0.7,normed = True)
plt.grid()
plt.xlabel('Pérdida o ganancia')
plt.show()
mu, sigma = np.mean(dt), np.std(dt)
normal = st.norm(mu, sigma)
print('El valor esperado de pérdida/ganancia es',np.mean(dt))
print('El valor (pérdida o ganancia) más probable es',st.mode(dt))
print('La probabilidad de ganar dinero en 100 tiradas es',1-normal.cdf(1))
# Out:
# El valor esperado de pérdida/ganancia es -13.344
# El valor (pérdida o ganancia) más probable es ModeResult(mode=array([-4]), count=array([170]))
# La probabilidad de ganar dinero en 100 tiradas es 0.235767726481

# %%
#Pregunta d
tj = []
for j in range(1000):
    c,s,t = 0,0,0
    d=30
    while d >= 0:
        x = np.random.randint(0,2)
        if x == 0:
            c += 1
            d -= 1
        else:
            s += 1
            d -= 1
        t += 1
        if abs(s-c) == 3:
            d +=8
            c,s = 0,0
            tj.append(t)
        else:
            tj.append(t)
    j+=1
print('El promedio de tiros antes de quedarte sin dinero es',np.mean(tj))
mu, sigma = np.mean(tj), np.std(tj)
normal = st.norm(mu, sigma)
print('La probabilidad de hacer +150 tiradas',1-normal.cdf(150))
plt.hist(tj,20,alpha=0.7,normed = True)
plt.grid()
plt.xlabel('Tiros jugados')
plt.show()
# Out:
# El promedio de tiros antes de quedarte sin dinero es 257.759321011
# La probabilidad de hacer +150 tiradas 0.651021191578

# %% [markdown]
# ## 2. Kitchen appliances

# %% [markdown]
# Máquinas vendidas|2|3|4|5|6|
# -----------------|-|-|-|-|-|
# Número de días|4|7|8|5|1|

# %% [markdown]
# #### Código

# %%
m = [2,3,4,5,6]
d = [4,7,8,5,1]
prob = d/np.sum(d)
prom = np.sum((m*prob))
print('El promedio de venta es de',prom)
plt.bar(m,d)
plt.xlabel("Días de venta")
plt.ylabel("Ventas")
plt.title("Gráfico de ventas")
plt.show()
# Out:
# El promedio de venta es de 3.68

# %% [markdown]
# ## 3. Rustbelt Manufacturing Company

# %% [markdown]
# >El tiempo requerido por la cuadrilla para reparar una máquina tiene una distribución uniforme durante el intervalo de 0 a dos veces
# la media, donde la media depende del tamaño de la cuadrilla. La media es de 4 horas con dos miembros de la cuadrilla, 3 horas con tres miembros de la cuadrilla y 2 horas con cuatro miembros de la cuadrilla.
# El tiempo entre las interrupciones de alguna máquina tiene una distribución uniforme de entre 3.5 y 9 horas.

# %% [markdown]
# #### Código

# %%
t = []
for i in range (1000):
    cuad = np.random.uniform(0,8)
    esp = np.random.uniform(3.5,9)
    tt = cuad+esp
    t.append(tt)
    i += 1
print('El promedio de tiempo en que una máquina tarda en ser reparada por una cuadrilla de 2 es de',np.mean(t),'horas')
plt.hist(t,normed=True)
plt.grid()
plt.show()
# Out:
# El promedio de tiempo en que una máquina tarda en ser reparada por una cuadrilla de 2 es de 10.1686598657 horas

# %% [markdown]
# ## 4. Juego de dados

# %% [markdown]
# >Él gana si la primera tirada resulta en una suma de 7 u 11 o, alternativamente, si la primera suma es 4, 5, 6, 8, 9 o 10 y la misma suma reaparece antes de que aparezca una suma de 7. Por el contrario, pierde si la primera tirada resulta en una suma de 2, 3 ó 12 o, alternativamente, si la primera suma es 4, 5, 6, 8, 9 o 10 y aparece una suma de 7 antes de la primera suma reaparece.

# %% [markdown]
# #### Código

# %%
tj = []
d = 500
p = [] # Ganar = 1, perder = 0
for i in range(10000):
    t=0
    d1 = np.random.randint(1,7)
    d2 = np.random.randint(1,7)
    t += 1
    if d1+d2 == 7 or d1+d2 == 11:
        p.append(1)
    elif d1+d2 == 2 or d1+d2 == 3 or d1+d2 == 12:
        p.append(0)
    else:
        boton = d1+d2
        d1 = np.random.randint(1,7)
        d2 = np.random.randint(1,7)
        sd = d1+d2
        t += 1
        while sd != boton and sd != 7:
            d1 = np.random.randint(1,7)
            d2 = np.random.randint(1,7)
            sd = d1+d2
            t += 1
        if sd == boton:
            p.append(1)
        elif sd == 7:
            p.append(0)
    tj.append(t)
    i += 1

# %%
#Pregunta a
print('La probabilidad de ganar corriendo 10,000 simulaciones es',np.count_nonzero(p)/len(p))
# Out:
# La probabilidad de ganar corriendo 10,000 simulaciones es 0.4905

# %%
#Pregunta b
dt = []
for i in range(10000):
    j=0
    d=500
    while j < 10:
        d1 = np.random.randint(1,7)
        d2 = np.random.randint(1,7)
        t += 1
        if d1+d2 == 7 or d1+d2 == 11:
            d += 50
            j += 1
            dt.append(d)
        elif d1+d2 == 2 or d1+d2 == 3 or d1+d2 == 12:
            d -= 50
            j += 1
            dt.append(d)
        else:
            boton = d1+d2
            d1 = np.random.randint(1,7)
            d2 = np.random.randint(1,7)
            sd = d1+d2
            while sd != boton and sd != 7:
                d1 = np.random.randint(1,7)
                d2 = np.random.randint(1,7)
                sd = d1+d2
            if sd == boton:
                d += 50
            elif sd == 7:
                d -= 50
            dt.append(d)
            j += 1
    i += 1

# %%
print('El valor esperado de tu dinero después de 10 juegos es',np.mean(dt))
print('El valor más probable de tu dinero es',st.mode(dt))
g = []
for i in range(len(dt)):
    if dt[i] > 500:
        g.append(dt[i])
    i += 1
print('La probabilidad de ganar dinero es',len(g)/len(dt))
# Out:
# El valor esperado de tu dinero después de 10 juegos es 496.259
# El valor más probable de tu dinero es ModeResult(mode=array([450]), count=array([17229]))
# La probabilidad de ganar dinero es 0.40244

# %% [markdown]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#808080; background:#fff;">
# Created with Jupyter by José Raúl Gallardo and José Antonio Quintero.
# </footer>
